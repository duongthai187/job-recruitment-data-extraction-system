# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
import re
import html

def decode_special_string(input_str):
    # Tìm các chuỗi Unicode và giải mã
    unicode_matches = re.finditer(r'\\u([0-9a-fA-F]{4})', input_str)
    decoded_str = input_str
    for match in unicode_matches:
        unicode_str = match.group(0)
        unicode_char = chr(int(unicode_str[2:], 16))
        decoded_str = decoded_str.replace(unicode_str, unicode_char)

    # Giải mã các ký tự HTML
    decoded_str = html.unescape(decoded_str)

    return decoded_str
# for json_string in skill:
#     if "<\\/span" in json_string:
#         decoded_string = decode_special_string(json_string)
#         print(decoded_string)

# for json_string in benefit:
#     if "<\\/span" in json_string:
#         decoded_string = decode_special_string(json_string)
#         print(decoded_string)

# %%
url = "https://itnavi.com.vn/ajax/get-job-by-id/24424"
# Gửi yêu cầu GET đến URL và lấy dữ liệu JSON
response = requests.get(url)
data = response.json()
with open("output.json", 'w', encoding = 'utf-8') as json_file:
    json.dump(data, json_file, default = str,  indent=4)

# %%
# root = "<div class=\"imy-5 paragraph\">\n\n<p>We are looking for <strong>Quality Assurance Lead</strong>, who will be the key member to manage and drive QA excellence in the scrum teams. Having insights into the QAs in the scrum teams and delivering the product from discovery to launch.</p><ul>\n<li>Work closely with other QA, engineers, analysts, and product owners to identify testing areas across the deliverables.</li>\n<li>Oversee the creation and execution of test plans and testing strategies for the scrum teams.</li>\n<li>Liaise with other QA managers and leads for overall end-to-end testing plan and ensure quality releases, reduce the risk/the bug that might have in all environments.</li>\n<li>Guide the automation testing efforts and liaise with other QA leads to ensure any developed QA frameworks are reusable across similar technologies.</li>\n<li>Evangelize the QA practice and the QA professionals in the HUB.</li>\n<li>Communicate status, risks, and issues to senior management and team members.</li>\n<li>Drive QA process and standards change to benefit high-performing teams.</li>\n<li>Recruit, train, and coach QA engineers and ensure they have a great onboarding experience.</li>\n<li>People management and development planning of up to 4 to 7 QA engineers</li>\n</ul>\n</div>\n<div class=\"imy-5 paragraph\">\n<h2>Yêu cầu công việc</h2>\n<p><strong>Essential:</strong></p><ul>\n<li>2 years in a lead role for QA / Testing on a major project.</li>\n<li>5- 7 years experience in QA / Testing, preferably in finance.</li>\n<li><strong>Knowledge and strong experience in API Testing, Mobile Testing, Performance Testing and Microservices.</strong></li>\n<li>Experience in the Digital domain (preferably in banking) and QA process in an Agile or Scrum delivery.</li>\n<li>Strong knowledge of multiple automated test tools and project/system development life cycles.</li>\n<li>Excellent organizational skills and ability to concurrently inspire and direct QA practices and processes across multiple delivery teams.</li>\n<li>Experience with scripting languages such as Python, Java, etc., and working with QA in other countries from different cultural backgrounds will be an advantage.</li>\n<li>Able to communicate English well (write, read, speak, and listen).</li>\n</ul><p><strong>Desirable:</strong></p><ul>\n<li>Desire to engage and maintain working relationships with sponsors, business stakeholders, and developers alike.</li>\n<li>Experience in software engineer best practices</li>\n<li>Experience with exploratory testing and behavior-driven design.</li>\n<li>Experience with continuous delivery and integration</li>\n</ul>\n</div>\n<div class=\"imy-5 paragraph\">\n<h2>Tại sao bạn sẽ yêu thích làm việc tại đây</h2>\n<p>At TYME opportunities are here for the taking. If want to be part of our purpose and live and lead through our values, we can offer exciting development opportunities through expanded lateral roles, stretch assignments or people leadership.</p><p><strong>Some of our benefits:</strong></p><ul>\n<li>Meal and parking allowance are covered by the company.</li>\n<li>Full benefits and salary rank during probation.</li>\n<li>Insurances as per Vietnamese labor law and premium health care for you and your family without seniority compulsory</li>\n<li>Performance bonus of up to 2 months</li>\n<li>13th-month salary pro-rata</li>\n<li>15-day annual leave+ 3-day sick leave + 1 birthday leave + 1 Christmas leave</li>\n<li>SMART goals and clear career opportunities (technical seminar, conference, and career talk) - we focus on your development.</li>\n<li>Values-driven, international working environment, and agile culture.</li>\n<li>Overseas travel opportunities for training and work-related.</li>\n<li>Internal Hackathons and company events (team building, coffee run, blue card...)</li>\n<li>Work-life balance 40-hr per week from Mon to Fri.</li>\n</ul>\n</div>\n"
# root = "<div class=\"job-description mobile-box\">\n                                        \n                                        <div class=\"description\">\n                                                                                            - Giảng dạy một hoặc nhóm môn học thuộc chuyên ngành Công nghệ thông tin: Programming (.net/java), Networking, Database Design and Development (MS SQL, Winform), Website Design and Development (HTML, PHP, Framework), Planning a Computing Project, Software Development Life Cycles, Security, Business Intelligence (Python), Cloud Computing, Data Structure and Algorithms, Advance Programming (OOP, UML, Design Pattern), Application Development (ASP.NET/java web), Internet Of Things, Computing Research Project, Fundamentals of Artificial Intelligence (AI) and Intelligent System, Data Analytics, Machine Learning, Big Data Analytics and Visualization, Mobile;<br>\r\n<br>\r\nCHẾ ĐỘ ĐÃI NGỘ:<br>\r\n- Môi trường làm việc năng động, chuyên nghiệp<br>\r\n- Có mức thu nhập cạnh tranh (trả theo năng lực)<br>\r\n- Có cơ hội tham gia các hoạt động đào tạo nâng cao trình độ<br>\r\n<br>\r\nCHẾ ĐỘ ĐÃI NGỘ KHÁC (cho GV Full-time):<br>\r\n- Cơ hội được nhận hỗ trợ từ FPT Edu lên đến 200 triệu đồng khi tham gia học Tiến sĩ<br>\r\n- Thưởng bài báo được công bố quốc tế: mức thưởng lên đến 100 triệu đồng/bài<br>\r\n- Được nhận hỗ trợ khi tham gia hội nghị, hội thảo trong nước và quốc tế có bài tham luận: mức hỗ trợ lên đến 30 triệu đồng/người/năm<br>\r\n- Hưởng chế độ chăm sóc sức khỏe đặc biệt dành cho bản thân và gia đình (FPT care)<br>\r\n- Được đóng BHXH, BHYT, BHTN… theo quy định của Nhà nước<br>\r\n- Người nhà được hưởng chế độ ưu đãi học phí khi học tập tại Tổ chức Giáo dục ĐH FPT<br>\r\n- Các quyền lợi khác: du lịch nghỉ mát hàng năm, tham gia các hoạt động vui chơi giải trí...<br>\r\n<br>\r\nĐỊA ĐIỂM LÀM VIỆC<br>\r\n1. Cao đẳng Anh quốc FPT BTEC:  Tòa nhà FPT BTEC, Phố Trịnh Văn Bô, Xuân Phương, Nam Từ Liêm, Hà Nội<br>\r\n2. Trung tâm liên kết quốc tế: FPT Aptech - Tòa nhà Detech, Số 8, Tôn Thất Thuyết, Hà Nội\n                                                                                    </div>\n                                        <a class=\"view-more clickable\">Xem toàn bộ Mô Tả Công Việc</a>\n                                    </div>\n                                    <div class=\"job-requirements mobile-box\">\n                                        <h2>Yêu Cầu Công Việc</h2>\n                                        <div class=\"requirements\">\n                                                                                            - Tốt nghiệp Đại học trở lên ngành CNTT hoặc chuyên ngành liên quan<br>\r\n- Có kiến thức chuyên môn vững về các môn học mà mình phụ trách giảng dạy<br>\r\n- Yêu thích việc dạy học, thích làm việc với sinh viên, có phong cách giảng dạy cuốn hút, dễ hiểu<br>\r\n- Ưu tiên ứng viên từng làm việc ở vị trí tương đương hoặc có kinh nghiệm thực tế trong việc triển khai các dự án CNTT.\n                                                                                    </div>\n\n                                    </div>\n                                    <div class=\"what-we-offer mobile-box\">\n                                        <h2>Các Phúc Lợi Dành Cho Bạn</h2>\n                                        \n                                        <div class=\"benefits\">\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-dollar\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Thu nhập hấp dẫn theo năng lực ứng viên\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-user-md\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Hưởng chế độ chăm sóc sức khỏe đặc biệt dành cho bản thân và gia đình (FPT care)\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-plane\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Các quyền lợi khác: du lịch nghỉ mát hàng năm, tham gia các hoạt động vui chơi giải trí\n                                                    </div>\n                                                </div>\n                                                                                    </div>\n                                        \n                                    </div>\n                                    "
# root = "<div><p>&bull; Understand the customers&rsquo; needs, work with other consultants, support teams to complete design and testing documentation.</p>\r\n\r\n<p>&bull; Create technical design documents, coding, unit testing and for developed functionality of Microsoft Dynamics 365 for Finance and Operations or AX 2012 based on functional design documents.</p>\r\n\r\n<p>&bull; Create sharing knowledge documentation and share with Team.</p>\r\n\r\n<p>&bull; Provide support and expertise on development technologies and environments.</p>\r\n\r\n<p>&bull; Data migration, integration development and testing.</p>\r\n\r\n<p>&bull; Build and package customizations.</p>\r\n\r\n<p>&bull; Provides technical support to functional consultants, projects managers, sales and customers.</p></div>\n<h3>Yêu cầu:</h3>\n<div><p><strong>MUST HAVE</strong></p>\r\n\r\n<p>&bull; Good software programming skill, comprehensive language X++.</p>\r\n\r\n<p>&bull; Knowledge about Visual studio, comprehensive language C#, SQL.</p>\r\n\r\n<p><br />\r\n<strong>NICE TO HAVE</strong></p>\r\n\r\n<p>&bull; Web service is a PLUS. Knowledge about Dynamics 365 commerce retail development (MPOS, Retail Server, Data Synchronize) is a PLUS.</p>\r\n\r\n<p>&bull; Microsoft Dynamics 365 for Finance and Operations certificate is a PLUS. Experience with Dynamics 365 for Finance and Operations integration technology: Odata, Custom service, Consume external web service, Batch data API.</p>\r\n\r\n<p>&bull; Experience with development and customization in Dynamics 365 for Finance and Operations Good Dynamics 365 for Finance and Operations framework understanding: RunBase, SysOperation, Data management, reporting SSRS.</p>\r\n\r\n<p><strong>&bull; EDUCATION</strong></p>\r\n\r\n<p>Graduated from university, major Engineering in IT / MIS &ndash; Management Information System / BIS &ndash; Business Information System / Software Technology department</p></div>\n<h3>Chế độ:</h3>\n<div><p>Become a member of the leading Microsoft Dynamics Partner in Southeast Asia and join a firm of 70% Microsoft Dynamics Finance and Operations professional services in the Vietnam market.</p>\r\n\r\n<p>&bull; Self-develop a clear career path and personal development plan (IDP) with your managers.</p>\r\n\r\n<p>&bull; Join overseas training and travel opportunities.</p>\r\n\r\n<p>&bull; Work and develop consulting skills in large-scale projects with international partners.</p>\r\n\r\n<p>&bull; As a team member of very few &ldquo;Asia Pacific managed&rdquo; partners, you will have great opportunities to be trained, certified, and supported by Microsoft Corporation.</p>\r\n\r\n<p>&bull; To become a member of the largest Microsoft technology community with full access and resources to the latest technologies.</p>\r\n\r\n<p>&bull; Salary: 100% gross salary for SHUI contribution</p>\r\n\r\n<p>&bull; Allowance: transportation, mobile, travel</p>\r\n\r\n<p>&bull; Holidays: 11 public holidays by law and &frac12; day for Christmas</p>\r\n\r\n<p>&bull; Paid leaves: 12 annual leave, 4 person leave &amp; 6 sick leave, and other leave by law</p>\r\n\r\n<p>&bull; Bear with project-based attractive bonus schemes on your competence level. &bull; Get a special healthcare program for individuals and family members.</p>\r\n\r\n<p>&bull; Be up-skills by peers and managers.</p>\r\n\r\n<p>&bull; Corporate and Labour Union events: annual outing trip, entertainment, gifts and parties for special occasions, football club, sports contest, training, &hellip;</p></div>\n"
# root = data["data"]["job_content"]
# root = "<div class=\"job-description mobile-box\">\n                                        \n                                        <div class=\"description\">\n                                                                                            1. Mô tả công việc<br>\r\n- Xây dựng và triển khai kế hoạch bán hàng (các SPDV/Giải pháp Công nghệ thông tin) đối với tập khách hàng được giao.<br>\r\n- Xây dựng chân dung khách hàng, tìm kiếm khách hàng/đối tác bán hàng.<br>\r\n- Tiếp xúc thường xuyên, xây dựng mối quan hệ với khách hàng.<br>\r\n- Xác định yêu cầu của khách hàng; phối hợp với bộ phận giải pháp tư vấn, giới thiệu sản phẩm/giải pháp cho khách hàng.<br>\r\n- Đánh giá cơ hội, xây dựng phương án kinh doanh. Xây dựng đề xuất giá, đề xuất hồ sơ dự thầu, đàm phán ký kết hợp đồng; theo dõi và đôn đốc việc thực hiện hợp đồng.<br>\r\n- Tổ chức triển khai công tác bán hàng dẫn dắt: thực hiện tìm kiếm và ký thỏa thuận hợp tác với các đối tác; Thực hiện vận động, làm việc với các cơ quan quản lý nhà nước để tạo điều kiện cho các đơn vị bán hàng, phát triển dịch vụ. Thực hiện tìm kiếm và ký thỏa thuận hợp tác với các đối tác để tích hợp dịch vụ vào các ứng dụng như các cổng dịch vụ công, các phần mềm ứng dụng của các doanh nghiệp. Thực hiện phát triển các đối tác, các đại lý tập trung để triển khai bán hàng toàn quốc.<br>\r\n- Phối hợp các bộ phận thực hiện các hoạt động chăm sóc sau bán hàng, tiếp nhận yêu cầu nâng cấp, mở rộng dịch vụ; tìm kiếm cơ hội bán hàng mới từ khách hàng.\n                                                                                    </div>\n                                        <a class=\"view-more clickable\">Xem toàn bộ Mô Tả Công Việc</a>\n                                    </div>\n                                    <div class=\"job-requirements mobile-box\">\n                                        <h2>Yêu Cầu Công Việc</h2>\n                                        <div class=\"requirements\">\n                                                                                            2. Yêu cầu<br>\r\n- Tốt nghiệp chuyên ngành: CNTT, Viễn thông, Tin học, Kinh tế; Quản trị kinh doanh; Marketing, CNTT….<br>\r\n- Kỹ năng: đàm phán, kỹ năng lập kế hoạch và làm việc nhóm, kỹ năng giao tiếp, thuyết trình, ưu tiên ứng viên có kỹ năng bán hàng, sử dụng thành thạo các ứng dụng vi tính văn phòng.<br>\r\n- Chủ động, nhanh nhẹn, quyết liệt trong công việc.<br>\r\n3. Quyền lợi<br>\r\n- Mức lương hấp dẫn, cạnh tranh, không giới hạn trần mức lương được hưởng.<br>\r\n- Được hưởng phụ cấp ăn ca: theo quy định của Tổng công ty.<br>\r\n- Được tham gia đóng bảo hiểm theo qui định Nhà nước, hưởng các phúc lợi hấp dẫn từ Tập đoàn VNPT.<br>\r\n- Được làm việc trong môi trường năng động, chuyên nghiệp, nhiều cơ hội thăng tiến.<br>\r\n- Được đào tạo theo yêu cầu công việc.<br>\r\n- Ký hợp đồng lao động sau 02 tháng thử việc.\n                                                                                    </div>\n\n                                    </div>\n                                    <div class=\"what-we-offer mobile-box\">\n                                        <h2>Các Phúc Lợi Dành Cho Bạn</h2>\n                                        \n                                        <div class=\"benefits\">\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-dollar\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Mức lương cạnh tranh, hấp dẫn: lên tới 500 triệu/năm\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-graduation-cap\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Chế độ chính sách hấp dẫn, đặc biệt trọng dụng nhân tài\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-trophy\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Cơ  hội thăng tiến cao trong công việc\n                                                    </div>\n                                                </div>\n                                                                                    </div>\n                                        \n                                    </div>\n                                    "
#root = "<div class=\"job-description mobile-box\">\n                                        \n                                        <div class=\"description\">\n                                                                                            - Nhận và Chuyển các yêu cầu công việc từ đối tác bên Nhật cho Team Việt Nam.<br>\r\n- Chuyến các thắc mắc và yêu cầu từ Team Việt Nam đến đối tác Nhật Bản.<br>\r\n- Quản lý tiến độ dự án, quản lý member và báo cáo cho đối tác Nhật Bản.<br>\r\n- Phân chia và giám sát công việc của các thành viên trong nhóm.<br>\r\n- Làm việc trực tiếp hàng ngày với đối tác Nhật Bản. Tham gia họp qua Skype, Chat trực tiếp bằng tiếng Nhật.<br>\r\n- Ứng viên không ở khu vực HCM có thể sắp xếp phỏng vấn online.\n                                                                                    </div>\n                                        <a class=\"view-more clickable\">Xem toàn bộ Mô Tả Công Việc</a>\n                                    </div>\n                                    <div class=\"job-requirements mobile-box\">\n                                        <h2>Yêu Cầu Công Việc</h2>\n                                        <div class=\"requirements\">\n                                                                                            - Tốt nghiệp Đại học (ưu tiên các trường Đại học chuyên ngành công nghệ thông tin hoặc điện tử viễn thông).<br>\r\n- Kỹ năng đọc/viết tài liệu kỹ thuật và giao thiếp tốt bằng tiếng Nhật (tương đương tiếng Nhật N2 trở lên).<br>\r\n- Có kinh nghiệm ít nhất 1 năm trở lên với vị trí tương ứng.<br>\r\n- Phải có kinh nghiệm trong lĩnh vực Web Development.<br>\r\n- Có kinh nghiệm trong lĩnh vực Mobile Development: phát triển ứng dụng cho các nền tảng di động như iOS, Android.<br>\r\n- Chủ động và ý thức trách nhiệm cao, sẵn sàng học hỏi, chăm chỉ.<br>\r\n- Có thể linh hoạt sắp xếp thời gian làm việc sao cho đảm bảo tiến độ đối tác yêu cầu.<br>\r\n- Ưu tiên cho ứng viên đã làm việc tại Nhật Bản hoặc có kinh nghiệm làm việc với đối tác Nhật Bản.<br>\r\n- Chi tiết khác trao đổi thêm khi phỏng vấn.<br>\r\n<br>\r\n***Quyền lợi dành cho bạn:<br>\r\n- Mức lương xứng đáng với năng lực.<br>\r\n- Thử việc hưởng 100% lương.<br>\r\n- Đánh giá lương: 6 tháng/lần, lương tháng 13, thưởng dự án.<br>\r\n- Môi trường làm việc chuyên nghiệp, năng động, trẻ trung.<br>\r\n- Cơ hội học tiếng Nhật, tham gia các khóa đào tạo tại Nhật Bản.<br>\r\n- Team building (3 tháng/lần), Tiệc khởi động dự án, du lịch công ty hàng năm.<br>\r\n- Thể thao: bóng đá, bóng bàn, cầu lông, bi lắc, ... Hoạt động ngoại khóa thú vị và phúc lợi khác (chế độ thâm niên, bảo hiểm sức khỏe, …) theo quy định của công ty.<br>\r\n- Thời gian làm việc: thứ hai – thứ sáu (8h30 – 17h30), nghỉ thứ bảy và chủ nhật hàng tuần, nghỉ lễ theo luật lao động Việt Nam, nghỉ ngày sinh nhật.<br>\r\n<br>\r\n***Hồ sơ xin việc:<br>\r\n- Gửi CV bằng tiếng Nhật (và tiếng Anh)\n                                                                                    </div>\n\n                                    </div>\n                                    <div class=\"what-we-offer mobile-box\">\n                                        <h2>Các Phúc Lợi Dành Cho Bạn</h2>\n                                        \n                                        <div class=\"benefits\">\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-dollar\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Thưởng dự án, lương tháng 13.\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-file-image-o\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">12+ ngày phép, nghỉ sinh nhật, ...\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-glass\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">đá banh, cầu lông, chạy bộ\n                                                    </div>\n                                                </div>\n                                                                                    </div>\n                                        \n                                    </div>\n                                    "
#root = "<div><ul>\r\n\t<li>Trao đổi v&agrave; hiểu s&acirc;u sắc y&ecirc;u cầu từ kh&aacute;ch h&agrave;ng, hiểu nội dung dự &aacute;n để triển khai cho ph&iacute;a Off-shore (th&ocirc;ng qua trao đổi bằng chat/email/conference-call/trao đổi trực tiếp v&agrave; dịch thuật c&aacute;c t&agrave;i liệu/email/chat của dự &aacute;n từ Nhật sang Việt v&agrave; ngược lại)</li>\r\n\t<li>Phụ tr&aacute;ch trao đổi Q&amp;A giữa Off-shore v&agrave; kh&aacute;ch h&agrave;ng, điều chỉnh c&aacute;c vấn đề như thay đổi specs, timeline, effort với người chịu tr&aacute;ch nhiệm dự &aacute;n ở ph&iacute;a kh&aacute;ch h&agrave;ng vv...</li>\r\n\t<li>Theo d&otilde;i s&aacute;t sao tiến độ dự &aacute;n v&agrave; quản l&yacute; để đảm bảo chất lượng sản phẩm b&agrave;n giao cho kh&aacute;ch h&agrave;ng</li>\r\n\t<li>Nhận diện v&agrave; b&aacute;o c&aacute;o ngay cho c&aacute;c cấp quản l&yacute; v&agrave; c&aacute;c b&ecirc;n li&ecirc;n quan khi c&oacute; vấn đề kh&ocirc;ng mong muốn xảy ra đối với dự &aacute;n</li>\r\n\t<li>Hỗ trợ c&aacute;c Manager C&ocirc;ng ty trong c&aacute;c c&ocirc;ng việc như:<br />\r\n\t- Trao đổi v&agrave; họp với kh&aacute;ch h&agrave;ng<br />\r\n\t- Chuẩn bị v&agrave; đ&oacute;n tiếp kh&aacute;ch h&agrave;ng (tại Việt Nam hoặc đi c&ocirc;ng t&aacute;c nước ngo&agrave;i) khi cần thiết</li>\r\n\t<li>C&aacute;c c&ocirc;ng việc kh&aacute;c được giao bởi CEO, General Manager, v&agrave; c&aacute;n bộ quản l&yacute; trực tiếp</li>\r\n</ul></div>\n<h3>Yêu cầu:</h3>\n<div><p><strong>Kinh nghiệm:&nbsp;</strong></p>\r\n\r\n<ul>\r\n\t<li>Tốt nghiệp chuy&ecirc;n ng&agrave;nh CNTT hoặc c&oacute; &iacute;t nhất 2 năm kinh nghiệm trong lĩnh vực IT (ưu ti&ecirc;n c&aacute;c ứng vi&ecirc;n c&oacute; chứng chỉ li&ecirc;n quan)</li>\r\n\t<li>Ưu ti&ecirc;n c&aacute;c bạn đ&atilde; c&oacute; kinh nghiệm l&agrave;m việc tại Nhật với kh&aacute;ch h&agrave;ng Nhật (tối thiểu 6 th&aacute;ng)</li>\r\n\t<li>Tiếng Nhật tối thiểu N2 - N1 (chứng chỉ JLPT), hiểu v&agrave; giao tiếp trực tiếp với kh&aacute;ch h&agrave;ng bằng tiếng Nhật</li>\r\n\t<li>C&oacute; kinh nghiệm trao đổi về IT domain:&nbsp;<br />\r\n\t- Nghe hiểu được spec v&agrave; giải th&iacute;ch được vấn đề kỹ thuật/trạng th&aacute;i dự &aacute;n<br />\r\n\t- C&oacute; thể g&oacute;p &yacute; thảo luật cải thiện spec</li>\r\n\t<li>Hiểu biết văn h&oacute;a, x&atilde; hội Nhật Bản để giao tiếp</li>\r\n\t<li>Tiếng Anh: c&oacute; thể đọc hiểu t&agrave;i liệu kỹ thuật</li>\r\n\t<li>Kỹ thuật: C&oacute; kiến thức cơ bản về IT domain m&agrave; kh&aacute;ch h&agrave;ng y&ecirc;u cầu: phần mềm, phần cứng, website, mobile app, blockchain, AI...</li>\r\n</ul>\r\n\r\n<p><strong>Kỹ năng:&nbsp;</strong></p>\r\n\r\n<ul>\r\n\t<li>C&oacute; kỹ năng quản trị chung, kỹ năng giao tiếp với kh&aacute;ch h&agrave;ng v&agrave; giao tiếp nội bộ</li>\r\n\t<li>Sử dụng th&agrave;nh thạo c&aacute;c c&ocirc;ng cụ Office</li>\r\n\t<li>C&oacute; khả năng chịu &aacute;p lực v&agrave; cường độ c&ocirc;ng việc cao</li>\r\n</ul></div>\n<h3>Chế độ:</h3>\n<div><ul>\r\n\t<li><strong>Mức lương offer theo năng lực từ 20,000,000 - 50,000,000 VNĐ</strong></li>\r\n\t<li>Th&aacute;ng lương 13 v&agrave; Thưởng Doanh số (dựa tr&ecirc;n performance của c&aacute; nh&acirc;n v&agrave; kết quả kinh doanh thực tế của C&ocirc;ng ty)</li>\r\n\t<li>Ch&iacute;nh s&aacute;ch thưởng dự &aacute;n ri&ecirc;ng v&agrave; linh hoạt, sẽ được chia ngay khi dự &aacute;n được thanh to&aacute;n từ kh&aacute;ch h&agrave;ng</li>\r\n\t<li>Performance Review: checkpoint 2 lần/năm</li>\r\n\t<li>C&oacute; cơ hội thăng tiến ở vị tr&iacute; quan trọng</li>\r\n\t<li>Ng&agrave;y nghỉ cố định: Thứ 7, Chủ nhật v&agrave; c&aacute;c ng&agrave;y lễ theo Quy định của Nh&agrave; nước</li>\r\n\t<li>Được l&agrave;m việc với đồng nghiệp người Nhật v&agrave; c&oacute; cơ hội đi c&ocirc;ng t&aacute;c Nhật Bản</li>\r\n\t<li>Được đội ngũ BrSE nhiều kinh nghiệm hiện tại của C&ocirc;ng ty trực tiếp hỗ trợ v&agrave; đ&agrave;o tạo</li>\r\n\t<li>C&aacute;c hoạt động team-building thường xuy&ecirc;n v&agrave; du lịch c&ocirc;ng ty h&agrave;ng năm</li>\r\n\t<li>Hỗ trợ chi ph&iacute; đ&agrave;o tạo, thi chứng chỉ, cơ hội đ&agrave;o tạo, n&acirc;ng cao nghiệp vụ</li>\r\n\t<li>C&aacute;c chế độ bảo hiểm theo Quy định của Luật Lao Động Việt Nam hiện h&agrave;nh</li>\r\n</ul>\r\n\r\n<p><strong>Heligate với m&ocirc;i trường chuy&ecirc;n nghiệp, cởi mở, trao quyền v&agrave; đề cao sự s&aacute;ng tạo:</strong></p>\r\n\r\n<ul>\r\n\t<li>L&agrave;m việc c&ugrave;ng những đồng nghiệp trẻ, c&aacute;c Leader v&agrave; Mentor hỗ trợ s&aacute;t sao, nhiệt t&igrave;nh.</li>\r\n\t<li>Văn h&oacute;a học tập mạnh mẽ v&agrave; th&uacute;c đẩy ph&aacute;t triển</li>\r\n\t<li>Quy tr&igrave;nh ph&aacute;t triển phần mềm chặt chẽ</li>\r\n\t<li>Tham gia v&agrave;o c&aacute;c dự &aacute;n lớn, tiếp cận, trực tiếp x&acirc;y dựng v&agrave; l&agrave;m chủ những sản phẩm tr&ecirc;n nền c&ocirc;ng nghệ mới nhất</li>\r\n</ul>\r\n\r\n<p><strong>Tập trung hỗ trợ sự ph&aacute;t triển c&aacute; nh&acirc;n:</strong></p>\r\n\r\n<ul>\r\n\t<li>Được tư vấn, đồng h&agrave;nh v&agrave; hỗ trợ ph&aacute;t triển sự nghiệp c&ugrave;ng với hệ thống career path (ph&aacute;t triển theo hướng chuy&ecirc;n gia hoặc hướng quản l&yacute;)</li>\r\n\t<li>Được định hướng mục ti&ecirc;u c&aacute; nh&acirc;n, nh&oacute;m v&agrave; tổ chức</li>\r\n\t<li>Trao quyền l&agrave;m chủ</li>\r\n</ul></div>\n"
# root = "<div class=\"job-description mobile-box\">\n                                        \n                                        <div class=\"description\">\n                                                                                            1.\tQuản lý hệ thống hạ tầng<br>\r\n-\tQuản lý các hệ thống hạ tầng CNTT công ty (máy chủ, mạng máy tính, điện thoại, viễn thông, điện nhẹ) bao gồm các khía cạnh: quản lý các bản cập nhật/vá lỗi, kiểm soát sự thay đổi, quản lý workload hệ thống, quản trị tiêu thụ năng lượng của hệ thống, capacity management.<br>\r\n-\tQuản lý và vận hành hệ thống Tổng đài, Call Center của Bệnh viện.<br>\r\n-\tQuản lý và vận hành toàn bộ hệ thống hạ tầng và vận hành ứng dụng CNTT dùng chung trong Công ty.<br>\r\n<br>\r\n2.\tĐảm bảo hoạt động ổn định, hiệu quả của các hệ thống thông tin hiện có, hướng dẫn sử dụng hệ thống thông tin<br>\r\n-\tChịu trách nhiệm vận hành các hệ thống ứng dụng dung chung, đảm bảo chất lượng dịch vụ IT đáp ứng đúng cam kết (SLA).<br>\r\n-\tĐảm bảo hệ thống CNTT của Bệnh viện đáp ứng các yêu cầu tuân thủ chính sách CNTT của Công ty, Tập đoàn và bệnh viện.<br>\r\n-\tTổ chức tham gia triển khai các dự án CNTT trong phạm vi quản lý công việc.<br>\r\n-\tTổ chức cung cấp hỗ trợ kỹ thuật cho bộ phận CNTT tại cơ sở hoặc hỗ trợ trực tiếp người sử dụng khi có yêu cầu.<br>\r\n<br>\r\n3.\tVai trò quản lý<br>\r\n-\tQuản lý ngân sách<br>\r\n        + Lập kế hoạch chi phí hàng năm cho đầu tư và vận hành hệ thống hạ tầng.<br>\r\n        + Tổng hợp kế hoạch ngân sách hàng năm cho toàn bộ hệ thống CNTT bệnh viện.<br>\r\n-\tDự án: Quản lý danh mục dự án CNTT bệnh viện (hàng năm).<br>\r\n-\tTổ chức: lãnh đạo bộ phận CNTT gồm 4 Chuyên viên/Nhân viên<br>\r\n<br>\r\n4.\tVai trò định hướng<br>\r\n-\tTham gia xây dựng kế hoạch và lộ trình phát triển CNTT tại Bệnh viện.<br>\r\n-\tLàm đầu mối thực hiện kế hoạch  triển khai các ứng dụng doanh nghiệp.<br>\r\n-\tPhối hợp làm việc với các nhóm/phòng CNTT khác.<br>\r\n-\tĐầu mối phối hợp làm việc với các đối tác ngoài Bệnh viện trong việc vận hành hệ thống CNTT tại Bệnh viện.<br>\r\n-\tTương tác với các khách hàng nội bộ trong việc tiếp nhận và xử lý các yêu cầu hỗ trợ vận hành.\n                                                                                    </div>\n                                        <a class=\"view-more clickable\">Xem toàn bộ Mô Tả Công Việc</a>\n                                    </div>\n                                    <div class=\"job-requirements mobile-box\">\n                                        <h2>Yêu Cầu Công Việc</h2>\n                                        <div class=\"requirements\">\n                                                                                            YÊU CẦU CÔNG VIỆC<br>\r\n- Cử nhân trở lên chuyên ngành Khoa học máy tính, Công nghệ thông tin, Quản trị mạng<br>\r\n- Có tối thiểu 5 năm kinh nghiệm ở vị trí Quản lý về Công nghệ thông tin tại các Tập đoàn/Công ty có quy mô mang tính hệ thống, ưu tiên ứng viên có kinh nghiệm triển khai phần mềm quản lý bệnh viện (HIS)<br>\r\n- Chủ động, sáng tạo, có ý thức kỷ luật cao, khả năng chịu áp lực công việc và tinh thần làm việc nhóm.<br>\r\n- Thái độ làm việc nghiêm túc, có trách nhiệm.<br>\r\n<br>\r\nQUYỀN LỢI<br>\r\n- Thu nhập cạnh tranh phù hợp năng lực và kinh nghiệm làm việc.<br>\r\n- Được hưởng đầy đủ các chế độ phúc lợi theo quy định của Pháp luật và Tập đoàn: BHXH, BHYT, BHTN, Bảo hiểm sức khỏe cao cấp Sun Care, hỗ trợ nhà ở, công tác phí, chế độ thâm niên, chính sách an cư lạc nghiệp, Thưởng Lễ/Tết..., sử dụng các dịch vụ ưu đãi khác của Tập đoàn…<br>\r\n- Có nhiều cơ hội thăng tiến trong sự nghiệp.<br>\r\n- Được hưởng các chế độ phúc lợi khác theo quy định của Tập đoàn\n                                                                                    </div>\n\n                                    </div>\n                                    <div class=\"what-we-offer mobile-box\">\n                                        <h2>Các Phúc Lợi Dành Cho Bạn</h2>\n                                        \n                                        <div class=\"benefits\">\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-dollar\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Thưởng thoả đáng với năng lực cống hiến, thưởng các ngày lễ tết trong năm\n                                                    </div>\n                                                </div>\n                                                                                            <div class=\"benefit row\">\n                                                    <div class=\"benefit-icon col-xs-1\"><i class=\"fa fa-fw fa-lg fa-user-md\"></i>\n                                                    </div>\n                                                    <div class=\"benefit-name col-xs-11\">Được hưởng đầy đủ các chế độ phúc lợi theo quy định\n                                                    </div>\n                                                </div>\n                                                                                    </div>\n                                        \n                                    </div>\n                                    "
#root = "<div><p>&bull; Ph&aacute;t triển c&aacute;c hệ thống mới cho kh&aacute;ch h&agrave;ng Nhật Bản (phần mềm, ứng dụng li&ecirc;n quan mảng nghiệp vụ về thuế Nhật, t&iacute;nh to&aacute;n thuế t&agrave;i sản cố định v&agrave; nh&agrave; ở..).</p>\r\n\r\n<p>&bull; Tư vấn thiết kế giải ph&aacute;p, đ&oacute;ng g&oacute;p &yacute; kiến để ph&aacute;t triển sản phẩm/dự &aacute;n.</p>\r\n\r\n<p>&bull; Thực hiện estimate task, viết t&agrave;i liệu thiết kế, coding v&agrave; unit test.</p>\r\n\r\n<p>&bull; Trao đổi với team v&agrave; BrSE/BA để l&agrave;m r&otilde; y&ecirc;u cầu dự &aacute;n.</p>\r\n\r\n<p>&bull; B&aacute;o c&aacute;o định kỳ hoặc theo y&ecirc;u cầu cho quản l&yacute;</p></div>\n<h3>Yêu cầu:</h3>\n<div><ol>\r\n\t<li>Kiến thức, kỹ năng, kinh nghiệm:\r\n\t<ul>\r\n\t\t<li>Th&agrave;nh thạo Java Spring boot, Spring Batch, jUnit, Mockito, jdocs, OpenAPI.</li>\r\n\t\t<li>C&oacute; kinh nghiệm l&agrave;m việc với cơ sở dữ liệu PostgreSQL, SQLServer, MySQL, Oracle.</li>\r\n\t\t<li>C&oacute; kinh nghiệm l&agrave;m việc với Spring, Struts, tối ưu hệ thống, l&agrave;m việc tr&ecirc;n m&ocirc;i trường Linux l&agrave; lợi thế.</li>\r\n\t\t<li>Hiểu biết về ph&aacute;t triển Front-end (chỉ cần biết l&agrave;m front-end l&agrave; được, kh&ocirc;ng quan trọng ng&ocirc;n ngữ/framework: Javascript, TypeScript, Bootstrap&hellip;</li>\r\n\t\t<li>C&oacute; tối thiểu 03 năm kinh nghiệm lập tr&igrave;nh JAVA với dự &aacute;n thực tế trở l&ecirc;n.</li>\r\n\t\t<li>Biết đọc Basic detail, Spec của KH để hiểu logic nghiệp vụ v&agrave; viết được Detail design</li>\r\n\t\t<li>C&oacute; kinh nghiệm viết test case của unit test</li>\r\n\t\t<li>Ưu ti&ecirc;n ứng vi&ecirc;n c&oacute; kinh nghiệm ph&aacute;t triển dự &aacute;n mảng T&agrave;i ch&iacute;nh/Ng&acirc;n h&agrave;ng/BĐS.</li>\r\n\t</ul>\r\n\t</li>\r\n</ol></div>\n<h3>Chế độ:</h3>\n<div><p>&bull; Lương: Range lương: 20.000.000 - 30.000.000 VNĐ (hoặc&nbsp;Lương đ&agrave;m ph&aacute;n theo năng lực; )</p>\r\n\r\n<p>&bull; 13 th&aacute;ng lương/năm v&agrave; thưởng dự &aacute;n 2 lần/năm</p>\r\n\r\n<p>&bull; Phụ cấp ăn trưa 730.000 VNĐ, thưởng 300.000 VNĐ qu&agrave; sinh nhật v&agrave; c&aacute;c loại thưởng kh&aacute;c (Thưởng th&agrave;nh t&iacute;ch, thưởng c&aacute; nh&acirc;n xuất sắc, thưởng đạt chứng chỉ ngoại ngữ/chuy&ecirc;n m&ocirc;n từ 1.000.000 VNĐ - 5.000.000 VNĐ).</p>\r\n\r\n<p>&bull; Hỗ trợ chi ph&iacute; kh&oacute;a học &ocirc;n, lệ ph&iacute; thi chứng chỉ ngoại ngữ/chuy&ecirc;n m&ocirc;n. &bull; Bảo hiểm sức khỏe to&agrave;n diện GMO - Aon care (theo cấp)</p>\r\n\r\n<p>&bull; Được l&agrave;m việc trực tiếp với c&aacute;c kh&aacute;ch h&agrave;ng Nhật Bản. C&oacute; cơ hội onsite tại Nhật.</p>\r\n\r\n<p>&bull; Được hưởng c&aacute;c ph&uacute;c lợi kh&aacute;c như: Team-building h&agrave;ng th&aacute;ng, nghỉ m&aacute;t h&agrave;ng năm, kh&aacute;m sức khỏe định kỳ,...</p>\r\n\r\n<p>&bull; Tất cả c&aacute;c chế độ theo quy định của Luật Lao động Việt Nam (BHXH, BHYT, BHTN,...).</p>\r\n\r\n<p>&bull; Nghỉ ph&eacute;p năm v&agrave; c&aacute;c ng&agrave;y nghỉ lễ, Tết kh&aacute;c theo quy định của Nh&agrave; nước Việt Nam.</p>\r\n\r\n<p>&bull; M&ocirc;i trường l&agrave;m việc trẻ trung, năng động, c&oacute; lộ tr&igrave;nh v&agrave; cơ hội thăng tiến.</p></div>\n"
# root = "<div><p><strong>M&Ocirc; TẢ C&Ocirc;NG VIỆC:</strong></p>\r\n\r\n<ul>\r\n\t<li>Thực hiện c&aacute;c c&ocirc;ng việc li&ecirc;n quan đến nghiệp vụ Motion Graphic (Video Edit)</li>\r\n\t<li>Dựng Video Intro B&agrave;i giảng, dựng phim motion theo c&aacute;ch kể chuyện, animation 2D/3D</li>\r\n\t<li>Tham gia l&ecirc;n kế hoạch kịch bản video</li>\r\n\t<li>Thực hiện c&aacute;c c&ocirc;ng việc kh&aacute;c theo sự ph&acirc;n c&ocirc;ng của cấp quản l&yacute;.</li>\r\n\t<li>Chi tiết c&ocirc;ng việc sẽ được trao đổi trực tiếp khi phỏng vấn</li>\r\n</ul></div>\n<h3>Yêu cầu:</h3>\n<div><p><strong>Y&Ecirc;U CẦU C&Ocirc;NG VIỆC:</strong></p>\r\n\r\n<ul>\r\n\t<li>Tốt nghiệp cao đẳng trở l&ecirc;n</li>\r\n\t<li>C&oacute; khả năng về Design. Am hiểu về Edit Video V-log, truyền h&igrave;nh thực tế</li>\r\n\t<li>Sử dụng th&agrave;nh thạo c&aacute;c phần mềm Adobe Pr, Ae, Ai, Ps</li>\r\n\t<li>C&oacute; &iacute;t nhất 2 năm kinh nghiệm&nbsp; đảm nhận vị tr&iacute; tương đương</li>\r\n\t<li>C&oacute; t&iacute;nh tỉ mỉ, s&aacute;ng tạo trong c&ocirc;ng việc</li>\r\n\t<li>Cập nhật c&aacute;c xu hướng l&agrave;m video mới.</li>\r\n</ul>\r\n\r\n<p><strong>ƯU TI&Ecirc;N:</strong></p>\r\n\r\n<ul>\r\n\t<li>Th&agrave;nh thạo tiếng H&agrave;n (Ưu ti&ecirc;n ứng vi&ecirc;n c&oacute; bằng TOPIK)</li>\r\n\t<li>C&oacute; khả năng Design tốt am hiểu về video</li>\r\n\t<li>Năng động, s&aacute;ng tạo trong c&ocirc;ng việc</li>\r\n\t<li>C&oacute; khả năng l&agrave;m việc nh&oacute;m tốt</li>\r\n\t<li>C&oacute; tinh thần tr&aacute;ch nhiệm cao tận t&acirc;m với c&ocirc;ng việc v&agrave; c&oacute; &yacute; định gắn b&oacute; l&acirc;u d&agrave;i.</li>\r\n\t<li>Am hiểu về văn h&oacute;a, phong c&aacute;ch H&agrave;n Quốc</li>\r\n</ul></div>\n<h3>Chế độ:</h3>\n<div><p><strong>PH&Uacute;C LỢI:</strong></p>\r\n\r\n<ul>\r\n\t<li>Được tham gia gia đầy đủ chế độ đ&oacute;ng BHXH, BHYT, BHTN theo quy định nh&agrave; nước</li>\r\n\t<li>Cơ hội thăng tiến cao v&agrave; cơ hội ph&aacute;t triển nghề nghiệp d&agrave;nh cho những c&aacute; nh&acirc;n c&oacute; năng lực</li>\r\n\t<li>Thưởng lương th&aacute;ng 13</li>\r\n\t<li><strong>Mức lương thỏa thuận khi phỏng vấn</strong></li>\r\n\t<li>Chế độ ph&uacute;c lợi kh&aacute;c theo quy định của c&ocirc;ng ty</li>\r\n</ul></div>\n"
root = "<div class=\"imy-5 paragraph\">\n\n<p>- Code, unit Test cho các dự án<br>- Dùng framework Laravel có sẵn để tiến hành phát triển .</p>\n</div>\n<div class=\"imy-5 paragraph\">\n<h2>Yêu cầu công việc</h2>\n<p>Yêu cầu:</p><ul>\n<li><span>Tối thiểu 1 năm kinh nghiệm phát triển PHP Laravel Framework. </span></li>\n<li><span>Có kinh nghiệm làm việc với các hệ thống quản lý source code Git, SVN </span></li>\n<li><span>Có hiểu biết về lập trình hướng đối tượng, mô hình kiến trúc MVC </span></li>\n<li><span>Có kinh nghiệm về Front-end sử dụng JavaScript, HTML,CSS ,Bootstrap (Biết thêm Vue.js là 1 lợi thế). </span></li>\n<li><span>Đặc biệt biết xử lý về Responsive Web </span></li>\n<li><span>Có kiến thức về cơ sở dữ Liệu SQL Server hoặc mysql và biết sử dụng stored procedure (SQL Server) là 1 lợi thế.</span></li>\n<li>Môi trường phát triển: Windows biết sử dụng linux là 1 lợi thế.</li>\n</ul>\n</div>\n<div class=\"imy-5 paragraph\">\n<h2>Tại sao bạn sẽ yêu thích làm việc tại đây</h2>\n<p>- Được tham gia các dự án phát triển phần mềm với các đối tác hàng đầu Nhật Bản, nhiều cơ hội trở thành key person của Công ty.</p><p>- Được tham gia nghiên cứu &amp; học tập các công nghệ mới như : Big Data , RPA, IoT...</p><p>- Có cơ hội được tham gia khóa đào tạo trở thành kỹ sư cầu nối BrSE tại A.N.S Corporation tại Nhật Bản miễn phí (dành cho các ứng viên làm việc tại ANS Asia ít nhất 1 năm và có đủ điều kiện về tiếng Nhật)</p><p>- Có chế độ thưởng chuyến du lịch cho cả gia đình dành cho những nhân viên làm việc lâu năm tại Công ty (thưởng 3 năm, thưởng 5 năm,…). </p><p>Đặc biệt, thưởng 1 chuyến du lịch Nhật Bản dành cho nhân viên làm việc từ 7 năm tại Công ty</p><p>- Được làm việc trong môi trường trẻ trung, năng động, chuyên nghiệp, có cơ hội tham gia các khóa đào tạo chuyên môn nhằm nâng cao năng lực bản thân.</p><p>- Hưởng đầy đủ các chế độ về BHXH, BHYT, BHTN theo Luật Lao động Việt Nam. Có trợ cấp ăn trưa, trợ cấp nhà ở, đi lại và tham gia khóa học tiếng Nhật tại Công ty.</p><p>- Hàng năm được xét tăng lương 2 lần, thưởng doanh thu, thưởng tháng lương thứ 13.</p><p>- Hưởng các chế độ về hiếu hỷ, ốm đau..., được tham gia các hoạt động tập thể của Công ty như Du lịch hè hàng năm, Teambuilding hàng tháng, Happy day hàng tuần, các hoạt động thể thao (đá bóng, bơi lội,…)</p><p>- Nghỉ 12 ngày phép/năm, nghỉ các ngày lễ, Tết...theo quy định của pháp luật.</p><p> </p>\n</div>\n"
soup = BeautifulSoup(root, 'html.parser')
cleaned_root = soup.get_text(separator='').lower()

split_1 = ["\nyêu cầu:\n", "\nyêu cầu công việc\n"]
split_2 = ["\nchế độ:\n", "\ncác phúc lợi dành cho bạn\n", "\ntại sao bạn sẽ yêu thích làm việc tại đây\n"]
check = False
split_check_2 = ""
for split_string_1 in split_1:
    if split_string_1 in cleaned_root:
        MoTa = cleaned_root.split(split_string_1)[0]
        cleaned_root_TG = cleaned_root.split(split_string_1)[1]
        
for split_string_2 in split_2:
    if split_string_2 in cleaned_root_TG:
        split_check_2 += split_string_2
        check = True
if check == True:
    YeuCau = cleaned_root_TG.split(split_check_2)[0]
    PhucLoi = cleaned_root_TG.split(split_check_2)[1]
else:
    YeuCau = cleaned_root_TG
    PhucLoi = ""

# %%
print(MoTa)
# Out:
# - code, unit test cho các dự án- dùng framework laravel có sẵn để tiến hành phát triển .

# %%
print(YeuCau) # this
# Out:
# yêu cầu:
# tối thiểu 1 năm kinh nghiệm phát triển php laravel framework.
# có kinh nghiệm làm việc với các hệ thống quản lý source code git, svn
# có hiểu biết về lập trình hướng đối tượng, mô hình kiến trúc mvc
# có kinh nghiệm về front-end sử dụng javascript, html,css ,bootstrap (biết thêm vue.js là 1 lợi thế).
# đặc biệt biết xử lý về responsive web
# có kiến thức về cơ sở dữ liệu sql server hoặc mysql và biết sử dụng stored procedure (sql server) là 1 lợi thế.
# môi trường phát triển: windows biết sử dụng linux là 1 lợi thế.

# %%
print(PhucLoi)
# Out:
# - được tham gia các dự án phát triển phần mềm với các đối tác hàng đầu nhật bản, nhiều cơ hội trở thành key person của công ty.- được tham gia nghiên cứu & học tập các công nghệ mới như : big data , rpa, iot...- có cơ hội được tham gia khóa đào tạo trở thành kỹ sư cầu nối brse tại a.n.s corporation tại nhật bản miễn phí (dành cho các ứng viên làm việc tại ans asia ít nhất 1 năm và có đủ điều kiện về tiếng nhật)- có chế độ thưởng chuyến du lịch cho cả gia đình dành cho những nhân viên làm việc lâu năm tại công ty (thưởng 3 năm, thưởng 5 năm,…). đặc biệt, thưởng 1 chuyến du lịch nhật bản dành cho nhân viên làm việc từ 7 năm tại công ty- được làm việc trong môi trường trẻ trung, năng động, chuyên nghiệp, có cơ hội tham gia các khóa đào tạo chuyên môn nhằm nâng cao năng lực bản thân.- hưởng đầy đủ các chế độ về bhxh, bhyt, bhtn theo luật lao động việt nam. có trợ cấp ăn trưa, trợ cấp nhà ở, đi lại và tham gia khóa học tiếng nhật tại công ty.- hàng năm được xét tăng lương 2 lần, thưởng do
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://itnavi.com.vn/job-detail/net-dev-c-mvc5-5LVa4"

# Gửi yêu cầu GET đến URL và lấy nội dung HTML
response = requests.get(url)
html_content = response.text

# Sử dụng BeautifulSoup để phân tích cú pháp HTML
soup = BeautifulSoup(html_content, "html.parser")

# Tìm thẻ <i> có class "fas fa-users"
icon_i = soup.find("i", class_="fas fa-users")

# Nếu tìm thấy thẻ <i>, thì tìm thẻ <li> cùng cấp
if icon_i:
    print("find complete")
    parent_li = icon_i.find_parent("li")

    # Nếu tìm thấy thẻ <li>, thì tìm thẻ <p> cùng cấp
    if parent_li:
        sibling_p = icon_i.find_next_sibling("p")

        # In nội dung của thẻ <p> cùng cấp
        if sibling_p:
            print("Content of <p> at the same level as <i class='fas fa-users'>:")
            print(sibling_p.get_text(strip=True))
        else:
            print("Không tìm thấy thẻ <p> cùng cấp với <i class='fas fa-users'>.")
    else:
        print("Không tìm thấy thẻ <li> cùng cấp với <i class='fas fa-users'>.")
else:
    print("Không tìm thấy thẻ <i class='fas fa-users'>.")
# Out:
# find complete
# Content of <p> at the same level as <i class='fas fa-users'>:
# 3

# %%
script = "<link rel=\"stylesheet\" href=\"https://static.topcv.vn/v4/css/components/desktop/jobs/job-list-search-result.2e134b6e8b702a30.css\">\n\n<div class=\"job-list-search-result\">\n                                                    <div class=\"job-item-search-result\n                                 bg-highlight  job-ta\n                                \"\n                data-job-id=\"956172\" data-job-position=\"1\"\n                data-u-sr-id=\"kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\" data-box=\"BoxSearchResult\"\n                >\n                <div class=\"avatar\">\n                    <a target=\"_blank\" href=\"https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-tu-van-tai-chinh-thu-nhap-tu-8-20-trieu-thang-lam-viec-tai-van-phong-tan-binh-ho-chi-minh/956172.html?ta_source=JobSearchList_LinkDetail&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\">\n                        <img src=\"https://cdn-new.topcv.vn/unsafe/150x/filters:format(webp)/https://static.topcv.vn/company_logos/AmcpPRqWqWaI2jTLqCtnkypt3u1pwlJB_1673859660____5fcf1d02eb26a0612940fe9e2e6bc290.jpg\" class=\"w-100\" alt=\"CÔNG TY TÀI CHÍNH TRÁCH NHIỆM HỮU HẠN MỘT THÀNH VIÊN SHINHAN VIỆT NAM\"\n                            title=\"Nhân Viên Kinh Doanh/ Tư Vấn Tài Chính - (Thu Nhập Từ 8 - 20 Triệu/Tháng) - Làm Việc Tại Văn Phòng Tân Bình (Hồ Chí Minh)\">\n                    </a>\n                                    </div>\n                <div class=\"body\">\n                    <div class=\"body-content\">\n                        <div class=\"title-block\">\n                            <div>\n                                <h3 class=\"title\">\n                                    <div class=\"box-label-top\">\n                                        \n                                        \n                                        \n                                                                            </div>\n\n                                    <a target=\"_blank\"                                         href=\"https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-
">\n                    </a>\n                                    </div>\n                <div class=\"body\">\n                    <div class=\"body-content\">\n                        <div class=\"title-block\">\n                            <div>\n                                <h3 class=\"title\">\n                                    <div class=\"box-label-top\">\n                                        \n                                        \n                                        \n                                                                            </div>\n\n                                    <a target=\"_blank\"                                         href=\"https://www.topcv.vn/viec-lam/nhan-vien-tu-van-dich-vu-visa-cham-soc-khach-hang-biet-tieng-anh/1182817.html?ta_source=JobSearchList_LinkDetail&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\">\n                                        <span data-toggle=\"tooltip\" data-container=\"body\" data-placement=\"top\"\n                                            title=\"Nhân Viên Tư Vấn Dịch Vụ Visa - Chăm Sóc Khách Hàng (Biết Tiếng Anh)\">Nhân Viên Tư Vấn Dịch Vụ Visa - Chăm Sóc Khách Hàng (Biết Tiếng Anh)</span>\n                                                                            </a>\n                                </h3>\n                                <a class=\"company\" href=\"https://www.topcv.vn/cong-ty/cong-ty-tnhh-dau-tu-va-phat-trien-an-phu-quoc/157121.html\" data-toggle=\"tooltip\"\n                                    title=\"CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN AN PHÚ QUỐC\" data-placement=\"top\"\n                                    target=\"_blank\">CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN AN PHÚ QUỐC</a>\n\n                                                                    <div class=\"box-job-relevance-job\">\n                                        <i class=\"fa-solid fa-star\"></i>\n                                        <i style=\"display: none;\" class=\"fa-regular fa-star\"></i>\n                                        <span class=\"box-job-relevance-job_text\"></span>\n                                    </div>\n                                                            </div>\n\n\n                            <div class=\"box-right\">\n                                <label class=\"title-salary\">\n                                                                        15 - 20 triệu\n                                </label>\n                                                                    <p class=\"quick-view-job-detail\">Xem <span class=\"speed\">nhanh</span> <i\n                                            class=\"fa-solid fa-chevrons-right\"></i></p>\n                                                            </div>\n                        </div>\n\n                        \n\n                                            </div>\n\n\n                    <div class=\"info\">\n                        <div class=\"label-content\">\n                                                            <label class=\"address\" data-toggle=\"tooltip\" data-html=\"true\"\n                                    title=\"&lt;p style=&#039;text-align: left&#039;&gt;Hà Nội: Hai Bà Trưng&lt;/p&gt;\"\n                                    data-placement=\"top\">Hà Nội</label>\n                                                        <label class=\"time\">\n                                                                    Còn\n                                    <strong>30</strong>\n                                    ngày để ứng tuyển\n                                                            </label>\n\n                                                            <label class=\"address\" data-container=\"body\">\n                                    Cập nhật 2 giờ trước\n\n                                </label>\n                                                    </div>\n                        <div class=\"icon\">\n                                                            <button data-job-id=\"1182817\" data-apply-url=\"\" data-redirect-to=\"https://www.topcv.vn/viec-lam/nhan-vien-tu-van-dich-vu-visa-cham-soc-khach-hang-biet-tieng-anh/1182817.html?ta_source=JobSearchList_ButtonApplyFormCard&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\" class=\"btn btn-apply-now\">\n                                    <span>Ứng tuyển</span>\n                                </button>\n                                                                                        <div class=\"box-save-job\">\n                                    <a data-id=\"1182817\"\n                                        href=\"javascript:showLoginPopup('https://www.topcv.vn/tim-viec-lam-moi-nhat?sort=top_related&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397', 'Đăng nhập hoặc Đăng ký để lưu tin tuyển dụng')\"\n                                        class=\"save box-save-job-hover\" data-toggle=\"tooltip\"\n                                        title=\"Bạn phải đăng nhập để lưu tin\"><i class=\"fa-regular fa-heart\"></i></a>\n                                </div>\n                                                    </div>\n                    </div>\n                </div>\n            </div>\n                                <div class=\"job-item-search-result\n                                 bg-highlight  job-ta\n                                \"\n                data-job-id=\"1177545\" data-job-position=\"25\"\n                data-u-sr-id=\"kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\" data-box=\"BoxSearchResult\"\n                >\n                <div class=\"avatar\">\n                    <a target=\"_blank\" href=\"https://www.topcv.vn/viec-lam/tro-ly-tieng-trung/1177545.html?ta_source=JobSearchList_LinkDetail&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\">\n                        <img src=\"https://static.topcv.vn/v4/image/normal-company/logo_default.png\" class=\"w-100\" alt=\"VANDSTAD ACADEMY COMPANY\"\n                            title=\"Trợ Lý Tiếng Trung\">\n                    </a>\n                                    </div>\n                <div class=\"body\">\n                    <div class=\"body-content\">\n                        <div class=\"title-block\">\n                            <div>\n                                <h3 class=\"title\">\n                                    <div class=\"box-label-top\">\n                                        \n                                        \n                                        \n                                                                            </div>\n\n                                    <a target=\"_blank\"                                         href=\"https://www.topcv.vn/viec-lam/tro-ly-tieng-trung/1177545.html?ta_source=JobSearchList_LinkDetail&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\">\n                                        <span data-toggle=\"tooltip\" data-container=\"body\" data-placement=\"top\"\n                                            title=\"Trợ Lý Tiếng Trung\">Trợ Lý Tiếng Trung</span>\n                                                                            </a>\n                                </h3>\n                                <a class=\"company\" href=\"https://www.topcv.vn/cong-ty/vandstad-academy-company/151560.html\" data-toggle=\"tooltip\"\n                                    title=\"VANDSTAD ACADEMY COMPANY\" data-placement=\"top\"\n                                    target=\"_blank\">VANDSTAD ACADEMY COMPANY</a>\n\n                                                                    <div class=\"box-job-relevance-job\">\n                                        <i class=\"fa-solid fa-star\"></i>\n                                        <i style=\"display: none;\" class=\"fa-regular fa-star\"></i>\n                                        <span class=\"box-job-relevance-job_text\"></span>\n                                    </div>\n                                                            </div>\n\n\n                            <div class=\"box-right\">\n                                <label class=\"title-salary\">\n                                                                        500 - 1,000 USD\n                                </label>\n                                                                    <p class=\"quick-view-job-detail\">Xem <span class=\"speed\">nhanh</span> <i\n                                            class=\"fa-solid fa-chevrons-right\"></i></p>\n                                                            </div>\n                        </div>\n\n                        \n\n                                            </div>\n\n\n                    <div class=\"info\">\n                        <div class=\"label-content\">\n                                                            <label class=\"address\" data-toggle=\"tooltip\" data-html=\"true\"\n                                    title=\"&lt;p style=&#039;text-align: left&#039;&gt;Hồ Chí Minh: Bình Thạnh&lt;/p&gt;\"\n                                    data-placement=\"top\">Hồ Chí Minh</label>\n                                                        <label class=\"time\">\n                                                                    Còn\n                                    <strong>20</strong>\n                                    ngày để ứng tuyển\n                                                            </label>\n\n                                                            <label class=\"address\" data-container=\"body\">\n                                    Cập nhật 2 giờ trước\n\n                                </label>\n                                                    </div>\n                        <div class=\"icon\">\n                                                            <button data-job-id=\"1177545\" data-apply-url=\"\" data-redirect-to=\"https://www.topcv.vn/viec-lam/tro-ly-tieng-trung/1177545.html?ta_source=JobSearchList_ButtonApplyFormCard&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397\" class=\"btn btn-apply-now\">\n                                    <span>Ứng tuyển</span>\n                                </button>\n                                                                                        <div class=\"box-save-job\">\n                                    <a data-id=\"1177545\"\n                                        href=\"javascript:showLoginPopup('https://www.topcv.vn/tim-viec-lam-moi-nhat?sort=top_related&amp;u_sr_id=kR89zM6hsNwY0hYH4bDoCmG8l61ynraZ7WXjcqFl_1701285397', 'Đăng nhập hoặc Đăng ký để lưu tin tuyển dụng')\"\n                                        class=\"save box-save-job-hover\" data-toggle=\"tooltip\"\n                                        title=\"Bạn phải đăng nhập để lưu tin\"><i class=\"fa-regular fa-heart\"></i></a>\n                                </div>\n                                                    </div>\n                    </div>\n                </div>\n            </div>\n            </div>\n<script>\n</script>\n"

# %%
soup = BeautifulSoup(script, 'html.parser')
# Find the script tag containing JSON-LD data

json_ld_script = decode_special_string(json_ld_script)
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Scrapy_DA2\test.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> soup = BeautifulSoup(script, 'html.parser')
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> # Find the script tag containing JSON-LD data
# ----> <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> json_ld_script = decode_special_string(json_ld_script)
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> print(soup)
#
# NameError: name 'json_ld_script' is not defined

# %%
js = """{
  "@context": "https://schema.org/",
  "@type": "JobPosting",
  "title": "Senior Account Executive",
  "description": "<div><p>Our Account Executives&#39; ability to communicate with individuals from all walks of life makes them expert trouble-shooters. They are the agency&#39;s neural centers responsible for the seamless delivery of projects. Excellent planners, anticipate challenges solving them with a flawless plan of action.<br />
&nbsp;</p></div>
<h3>Yêu cầu:</h3>
<div><p>&nbsp;</p>

<ul>
	<li>Over 2 years experience in an advertising agency or related field</li>
	<li>Discuss and identify plans of action for projects</li>
	<li>Work closely with the wider consortium for resource planning</li>
	<li>Streamline resources for effective project delivery</li>
	<li>Coordinate with various departments</li>
	<li>Prepare costings and budget reports for upper management</li>
	<li>Work with external partners to manage project costs</li>
	<li>Monitor multiple projects simultaneously</li>
	<li>Set project delivery milestones&nbsp;</li>
</ul></div>
<h3>Chế độ:</h3>
<div><ul>
	<li>Working in a dynamic international environment&nbsp;</li>
	<li>Growing business</li>
	<li>Salary reviewed annually</li>
	<li>Once employees have passed probation and signed a labor contract, the employee will have other benefits such as annual leave days, bonus salary, social insurance, health insurance, unemployment insurance (Vietnamese Law), insurance benefits package (PTI Care), training programs, etc.</li>
</ul></div>
",
  "identifier": {
        "@type": "PropertyValue",
        "name": "CÔNG TY TNHH TMRW VIỆT NAM",
        "value": "4717"
      },
  "hiringOrganization" : {
    "@type": "Organization",
    "name": "CÔNG TY TNHH TMRW VIỆT NAM",
    "logo": "https://d3hi6wehcrq5by.cloudfront.net/itnavi-web/companies/39f6373cf2ae850fc23e45a1738ceb40.png?v=1699519692",
    "sameAs": "https://itnavi.com.vn/company/cong-ty-tnhh-tmrw-viet-nam"
  },
          "employmentType": ["FULL_TIME"],
    "datePosted": "2023-11-22",
  "validThrough": "2023-12-22",
  "jobLocation": {
    "@type": "Place",
    "address": {
      "@type": "PostalAddress",
      "streetAddress": "Quận Bình Thạnh",
      "addressRegion": "Hồ Chí Minh",
      "addressLocality": "Hồ Chí Minh",
      "postalCode": "10000-14000",
      "addressCountry": "10000-14000",
    }
  },
  "baseSalary": {
          "@type": "MonetaryAmount",
          "currency": "USD",
          "value": {
            "@type": "QuantitativeValue",
            "minValue": "580",
      "maxValue": "750",
      "unitText": "MONTH"
    }
  },
            "skills": "Microsoft Office skills, Oral Communication, Project Management"
      }"""

# %%
js = decode_special_string(js)

# %%
YeuCau = js.split("Yêu cầu:")[1].split("Chế độ:")[0]
YeuCau = YeuCau.replace("</h3>", "")
YeuCau = YeuCau.replace("<div>", "")
YeuCau = YeuCau.replace("<p>", "")
YeuCau = YeuCau.replace("</p>", "")
YeuCau = YeuCau.replace("<ul>", "")
YeuCau = YeuCau.replace("</ul>", "")
YeuCau = YeuCau.replace("</div>", "")
YeuCau = YeuCau.replace("<h3>", "")
YeuCau = YeuCau.replace("</li>", "")
YeuCau = YeuCau.replace("<li>", "")
# YeuCau = YeuCau.replace("\n", ". ")
print(YeuCau.strip())
# Out:
# Over 2 years experience in an advertising agency or related field
# 	Discuss and identify plans of action for projects
# 	Work closely with the wider consortium for resource planning
# 	Streamline resources for effective project delivery
# 	Coordinate with various departments
# 	Prepare costings and budget reports for upper management
# 	Work with external partners to manage project costs
# 	Monitor multiple projects simultaneously
# 	Set project delivery milestones

# %%
# Xóa dấu cách thừa, giữ lại dấu xuống dòng
cleaned_string = re.sub(r'\s+', ' ', YeuCau).strip()

# In ra kết quả
print(cleaned_string)
# Out:
# Over 2 years experience in an advertising agency or related field Discuss and identify plans of action for projects Work closely with the wider consortium for resource planning Streamline resources for effective project delivery Coordinate with various departments Prepare costings and budget reports for upper management Work with external partners to manage project costs Monitor multiple projects simultaneously Set project delivery milestones

# %%
date = js.split("\"validThrough\": \"")[1].split("\"")[0]
print(date)
# Out:
# 2023-12-22

# %%
response_html = requests.get("https://itnavi.com.vn/job-detail/net-dev-c-mvc5-5LVa4")
print(response_html.text)
# Out:
# <!doctype html>
# <html lang="vi">
# <head>
# <link rel="dns-prefetch" href="//itnavi.com.vn">
# <link rel="dns-prefetch" href="//fonts.googleapis.com">
# <link rel="dns-prefetch" href="//use.fontawesome.com">
# <link rel="dns-prefetch" href="//cdn.jsdelivr.net">
# <link rel="dns-prefetch" href="//cdnjs.cloudflare.com">
# <link rel="dns-prefetch" href="//i.imgur.com">
# <link rel="dns-prefetch" href="//schema.org">
# <link rel="dns-prefetch" href="//d3hi6wehcrq5by.cloudfront.net">
# <link rel="dns-prefetch" href="//www.googletagmanager.com">
# <link rel="dns-prefetch" href="//embed.tawk.to">
# <link rel="dns-prefetch" href="//www.facebook.com">
# <link rel="dns-prefetch" href="//twitter.com">
# <link rel="dns-prefetch" href="//www.instagram.com">
# <link rel="dns-prefetch" href="//www.linkedin.com">
# <link rel="dns-prefetch" href="//www.tiktok.com">
# <link rel="dns-prefetch" href="//www.dmca.com">
# <link rel="dns-prefetch" href="//images.dmca.com">
# ...

# %%
response_html.text.split("\"validThrough\": \"")[1].split("\"")[0]
# Out:
# '2023-11-30'

# %%
response_html = requests.get("https://itnavi.com.vn/job-detail/net-dev-c-mvc5-5LVa4")
soup = BeautifulSoup(response_html, "html.parser")
icon_i = soup.find("i", class_="fas fa-users")
if icon_i:
    sibling_p = icon_i.find_next_sibling("p")
    if sibling_p:
        SoLuong = sibling_p.get_text(strip=True)
    else:
        SoLuong = "Không có"
else:
    SoLuong = "Không có"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Scrapy_DA2\test.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> response_html = requests.get("https://itnavi.com.vn/job-detail/net-dev-c-mvc5-5LVa4")
# ----> <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> soup = BeautifulSoup(response_html, "html.parser")
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> icon_i = soup.find("i", class_="fas fa-users")
#       <a href='vscode-notebook-cell:/e%3A/Scrapy_DA2/test.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> if icon_i:
#
# File e:\Scrapy_DA2\venv\Lib\site-packages\bs4\__init__.py:315, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
# ...

# %%
import requests
import json
url = "https://careerbuilder.vn/search-jobs"

headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9,vi;q=0.8",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://careerbuilder.vn",
    "Referer": "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-trang-2-vi.html",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
    "X-Requested-With": "XMLHttpRequest",
    # Include other headers as needed
}


response = requests.post(url, headers=headers)

# Print the response content or perform other actions with the response
json_data = response.json()
with open("ouptut_career_2.json", "w", encoding= 'utf-8') as file:
    json.dump(json_data, file, default=str, ensure_ascii= False, indent= 4)

# %%
data_json = json.loads(response.text)
print(type(data_json))
# Out:
# <class 'dict'>

# %%
import requests
import json
from urllib.parse import urlencode
data_one = 'a:1:{s:4:"PAGE";s:2:"10";}'
data_two = 'a:0:{}'

# Mã hóa dữ liệu
encoded_data_one = urlencode({'dataOne': data_one})
encoded_data_two = urlencode({'dataTwo': data_two})

# Kết hợp dữ liệu
payload = f"{encoded_data_one}&{encoded_data_two}"
url = "https://careerbuilder.vn/search-jobs"


headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9,vi;q=0.8",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://careerbuilder.vn",
    "Referer": "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-trang-10-vi.html",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0"
}

response = requests.post(url, headers=headers, data = payload)

json_data = response.json()
with open("ouptut_career_2.json", "w", encoding= 'utf-8') as file:
    json.dump(json_data, file, default=str, ensure_ascii= False, indent= 4)

# %%
for i in range(len(json_data["data"])):
    print(json_data["data"][i]["LINK_JOB"])
# Out:
# https://careerbuilder.vn/vi/tim-viec-lam/ho-chuyen-vien-cao-cap-quan-tri-rui-ro-cong-nghe-va-the-khoi-quan-ly-rui-ro.35BDE80F.html
# https://careerbuilder.vn/vi/tim-viec-lam/truong-phong-tuyen-dung-tuyen-gap.35BDE7EE.html
# https://careerbuilder.vn/vi/tim-viec-lam/digital-communications.35BDE7CD.html
# https://careerbuilder.vn/vi/tim-viec-lam/dong-nai-chuyen-vien-tu-van-tra-gop-kenh-o-to.35BDE74A.html
# https://careerbuilder.vn/vi/tim-viec-lam/tro-ly-kinh-doanh-cong-ty-logistic-nhat-ban-hung-yen-12-20-trieu.35BDE729.html
# https://careerbuilder.vn/vi/tim-viec-lam/ky-su-phat-trien-fullstack-khoi-cntt.35BDE7EC.html
# https://careerbuilder.vn/vi/tim-viec-lam/tp-hoa-binh-cua-hang-truong.35BDE82E.html
# https://careerbuilder.vn/vi/tim-viec-lam/ivyprep-admission-counselor.35BDE747.html
# https://careerbuilder.vn/vi/tim-viec-lam/truong-phong-thiet-ke.35BDE6FA.html
# https://careerbuilder.vn/vi/tim-viec-lam/dak-lak-chuyen-vien-tu-van-bao-hiem-kenh-lien-doanh-ngan-hang-bidv.35BDE6B8.html
# ...

# %%
url = 'https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-trang-10-vi.html'
page_number_str = ''.join(c for c in url.split('-')[-2] if c.isdigit())
print(url.split('-')[-2])
page_number = int(page_number_str)
print(page_number)
# Out:
# 10
# 10

# %%
url = "https://careerbuilder.vn/vi/tim-viec-lam/general-accountant-hcm-hn.35BDE72A.html"
id = url.split(".")[-2]
print(type(id))
# Out:
# <class 'str'>

# %%
import requests
from urllib.parse import urlencode
import time

# Lấy timestamp hiện tại
current_timestamp = str(int(time.time()))



url = "https://www.topcv.vn/tim-viec-lam-moi-nhat?"

headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9,vi;q=0.8",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Content-Length": "0",
    "Origin": "https://www.topcv.vn",
    "Referer": "https://www.topcv.vn/tim-viec-lam-moi-nhat?sort=top_related&page=3",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
    "X-Csrf-Token": "aI9UpxBQOorRNsJ0zwZFjFQSlimduVbPFW61RjXS",
    "X-Requested-With": "XMLHttpRequest"
}
payload = {
    "sort": "top_related",
    "page": "3",
    "u_sr_id": "1nXR19sIMw3tMJrs0Q2tahQzHHv1NjaOsk4aZNfB_" + current_timestamp
}

# Mã hóa payload và thêm vào URL
payloads = f"sort={payload["sort"]}&page={payload["page"]}&u_sr_id={payload["u_sr_id"]}"
# Gửi yêu cầu POST với payload
response = requests.post(url_with_payload, headers=headers)



# In ra nội dung phản hồi
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>Opps! 500 Internal Server Error!</title>
#     <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N3ZZ7MK');</script>
# <!-- End Google Tag Manager -->
#
#
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-F385SHE0Y3"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-F385SHE0Y3');
# </script>
#     <!-- ta -->
# <script>
#     window.header = {
# ...

# %%
import time

# Lấy timestamp hiện tại
current_timestamp = str(int(time.time()))

print(current_timestamp)
# Out:
# 1701319606

# %%
import requests

url = "https://www.vietnamworks.com/"
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'Host': 'www.vietnamworks.com',
    'Origin': 'null',
    'Referer': 'https://www.vietnamworks.com/',
    'Sec-Ch-Ua': '"Microsoft Edge";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0',
}

response = requests.get(url, headers=headers)

# In ra kết quả
print(response.status_code)
print(response.text)
# Out:
# 200
# ...

# %%
import requests
from random import randint
response = requests.get(
  url='https://headers.scrapeops.io/v1/user-agents',
  params={
      'api_key': 'cca4ced0-490d-41a0-b258-46f2ad7e74b3',
      'num_results': '100'}
)
json_response = response.json()
user_agents_list = json_response.get('result', [])
random_index = randint(0, len(user_agents_list) - 1)
print(len(user_agents_list))
# Out:
# 96
